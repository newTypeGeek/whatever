# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# \begin{align}
#     x(t) \; = \;  \big(x_{\infty} - x_{0}\big) \, \big( 1 - e^{-t/\tau}) \, + \, x_{0} \, + \, \eta(t)
# \end{align}

# %%
n = 60*4
x_inf = 5.0
x_0 = 10.0
tau = 30

noise_mean = 0.
noise_std = 0.3

index = pd.date_range("2020-01-01", freq="1T", periods=n, name="timestamp")

t = np.arange(0, n)
x = (x_inf - x_0) * (1 - np.exp(-t/tau)) + x_0  + np.random.normal(noise_mean, noise_std, t.shape)


df = pd.DataFrame(data={"x": x}, index=index)
df
# Out:
# /var/folders/jt/qc2v1nvx07lcdmb5wpxrtf1w0000gp/T/ipykernel_6451/3104912421.py:9: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   index = pd.date_range("2020-01-01", freq="1T", periods=n, name="timestamp")
#                             x
# timestamp
# 2020-01-01 00:00:00  9.744159
# 2020-01-01 00:01:00  9.888126
# 2020-01-01 00:02:00  9.655903
# 2020-01-01 00:03:00  9.513927
# 2020-01-01 00:04:00  8.994935
# ...                       ...
# 2020-01-01 03:55:00  5.075513
# 2020-01-01 03:56:00  5.153441
# 2020-01-01 03:57:00  5.263613
# 2020-01-01 03:58:00  4.650515
# 2020-01-01 03:59:00  4.750510
#
# [240 rows x 1 columns]

# %%
fig, ax = plt.subplots()
df.plot(ax=ax)

x_lim = ax.get_xlim()
ax.hlines(xmin=x_lim[0], xmax=x_lim[1], y=x_inf, color="red", linestyle="--")

ax.set_ylabel("x(t)")
# Out:
# Text(0, 0.5, 'x(t)')

# %%
df.hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'x'}>]], dtype=object)
